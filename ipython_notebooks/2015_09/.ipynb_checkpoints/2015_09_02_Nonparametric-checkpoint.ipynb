# %% [markdown]
# **Author**: J W Debelius<br/>
# **Date**: 27 August 2015<br/>
# **virtualenv**: power play

# %%
# %%javascript
# IPython.load_extensions('calico-spell-check', 'calico-document-tools')

# %% [markdown]
# # 1. Introduction

# %%
from __future__ import division

import matplotlib.pyplot as plt
import numpy as np
import scipy.stats
import statsmodels.api as sms
import statsmodels.formula.api as smf

import absloute_power.traditional as trad
import absloute_power.utils as ap

from scipy.stats import norm as Z


import pandas as pd

from skbio.stats.power import subsample_power

from absloute_power.traditional import calc_ttest_1

# %%
from matplotlib import rcParams



# Sets up plotting parameters so that the default setting is use to Helvetica
# in plots
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Helvetica', 'Arial']
rcParams['text.usetex'] = True

% matplotlib inline

# %% [markdown]
# We'll examine five common, simple statistical models where the power equation has been defined and employed. The emperical power implementations are based on the version described in [ref].
#
# We will examine statistical power for three tests dealing with normal distributions:
#
# * Case I t test
# * Case II (independent) t test
# * One way Analysis of Variance (ANOVA)
# * Pearson's R
# * Chi-Square
#
# We will perform 100 simulations of statistical power, comparing the power between 5 and 50 counts, with 5 observation intervals between. We'll set the critical value at 0.05.

# %%
num_rounds = 1000
counts = np.arange(5, 55, 10)
alpha = 0.05
distributions = {}

# %% [markdown]
# We'll also set a random seed, so that the results we get out are consistent.

# %%
np.random.seed(25)

# %% [markdown]
# # 2. Case I Test

# %% [markdown]
# A case I t-test checks if an observation is drawn from a sample. We are testing the alternatively hypotheses,
#
# $\begin{matrix}
# \textbf{H}_{0} & x = \bar{x} \\
# \textbf{H}_{1} & x \neq \bar{x}\\
# \end{matrix} \tag{2.1}$
#
# where $\bar{x}$ is the mean of the population, $x$ is the value being compared to the sample, $s$ is the standard devation of the sample, and there are $n$ observations in the sample.

# %% [markdown]
# ## 2.1 Test Statistic

# %% [markdown]
# The test statistic for the case I t test is given as
# $t = \frac{(\bar{x} - x)\sqrt{n}}{s} \tag{2.2}$
# The probability distribution follows a T distribution with $n-1$ degrees of freedom, where $n$ is the number of observations in the sample.
#
#
# For the emperical test, we will use the `scipy.stats.ttest_1samp` function, which returns a p value.

# %%
def emp_ttest_1(sample, x0=0):
    return scipy.stats.ttest_1samp(sample, x0)[1]

# %% [markdown]
# ## 2.2 Nonparametric Test

# %%
def emp_ttest_1_nonpar(sample, x0=0):
    scipy.stats.wilcoxon(sample - x0)[1]

# %% [markdown]
# ## 2.3 Effect Size

# %% [markdown]
# The effect size for a one-sample t test is Cohen's d, given by equation (2.3).
# $\begin{align*}
# d = \frac{\bar{x} - x_{0}}{s}
# \end{align*}\tag{2.3}$
# For a two-tailed test, we can treat this as an absloute magnitude, and then test $t > (1 - \alpha/2)$.

# %%
def cohen_d_one_sample(sample, x0=0):
    x1, s1 = sample.mean(), sample.std()
    return np.absolute(x1 - x0) / s1

# %% [markdown]
# ## 2.4 Noncentrality Paramter

# %% [markdown]
# The non centrality paramter for the statistic, $\lambda$ is given by
# $\begin{align*}
# \lambda &= \frac{t}{\sqrt{n}}\\
# &=\frac{1}{\sqrt{n}}\left(\frac{(\bar{x} - x)\sqrt{n}}{s}\right )\\
# &=\frac{(\bar{x} - x)}{s}
# \end{align*}\tag{2.4}$
#
# We will encorperate this in the power calculation. To allow for testing, the power calculation has been moved into a library.

# %% [markdown]
# ## 2.5 Simulation Parameters

# %% [markdown]
# We'll test the set of hypotheses,
#
# $\begin{matrix}
# \textbf{H}_{0} & 0 = \bar{x} \\
# \textbf{H}_{1} & 0 \neq \bar{x}\\
# \end{matrix} \tag{2.5}$
#
# where $\bar{x}$ is the mean of a sample drawn from a population.
#
# We'll test the means between 2 and 10 with standard deviations between 5 and 15, and sample sizes between 60 and 100 observations.

# %%
def ttest_1_simulate(mu_lim, sigma_lim, count_lims):
    # Gets the distribution parameters
    mu = np.random.randint(*mu_lim)
    sigma = np.random.uniform(*sigma_lim)
    n = np.random.randint(*count_lims)
    
    # Draws a sample that fits the parameters
    return [mu, sigma, n], [np.random.poisson(sigma, n)]

# %%
distributions['ttest_1'] = {'emp_test_fun': emp_ttest_1,
                            'non_test_fun': emp_ttest_1_nonpar,
                            'trad_test_fun': calc_ttest_1,
                            'sim_function': ttest_1_simulate,
                            'sim_parameters': [[0, 3], [0, 3], [125, 126]],
                            'other_sim_parameters': {},
                            'test_parameters': {'x0': 0},
                            'emp_parameters': {},
                            'effect_size': cohen_d_one_sample,
                             }

# %% [markdown]
# # 3. Case II T Test

# %% [markdown]
# The case II t test is a test for two independent samples, to determine if the samples are drawn from different distributions.
#
# $\begin{matrix}
# \textbf{H}_{0} & \bar{x}_{1} = \bar{x}_{2} \\
# \textbf{H}_{1} & \bar{x}_{1} \neq \bar{x}_{2}\\
# \end{matrix} \tag{3.1}$

# %% [markdown]
# ## 3.1 Test Statistic

# %% [markdown]
# There are several ways to calculate this t statistic, but we will operate on the assumption that the two populations have different variances, giving the most extensibe calculation of the test statistic. So,
#
# $\begin{align*}
# t &= \frac{\bar{x}_{1} - \bar{x}_{2}}{\sqrt{\frac{s_{1}^{2}}{n_{1}} + \frac{s_{2}^{2}}{n_{2}}}}\\
# &= \frac{\bar{x}_{1} - \bar{x}_{2}}{\sqrt{\frac{n_{2}s_{1}^{2} + n_{1}s_{2}^{2}}{n_{1}n_{2}}}}
# \end{align*}\tag{3.2}$
#
# The t statistic follows a T distribution with $df$ degrees of freedom, where $df$ is given as
# $df = \frac{(s_{1}^{2}/n_{1} + s_{2}^{2}/n_{2})^{2}}{(s_{1}^{2}/n_{1})^2/(n_{1}-1) + s_{2}^{2}/n_{2})^2/(n_{2}-1)} \tag{3.3}$
#
# For the sake of simplicity, we'll assume that $n_{1} = n_{2}$, which allows us to redefine equation (2.1) as
# $\begin{align*}
# t &= \frac{(\bar{x}_{1} - \bar{x}_{2})}{\sqrt{\frac{s_{1}^{2}}{n} + \frac{s_{2}^{2}}{n}}}\\
# &= \frac{\sqrt{n}(\bar{x}_{1} - \bar{x}_{2})}{\sqrt{s_{1}^{2} + s_{2}^{2}}}
# \end{align*}\tag{3.4}$
# which means the test statitic is now drawn from a t distribution with df degrees of freedom, where
# df is defined as
# $\begin{align*}
# df &= \left (n-1 \right ) \left (\frac{\left (s_{1}^{2} + s_{2}^{2}  \right )^{2}}{\left (s_{1}^{2} \right)^{2} + \left (s_{2}^{2}  \right )^{2}} \right )\\
# \end{align*}\tag{3.5}$
#
# For the emperical test, we can use the `scipy.stats.ttest_ind` function, which will return a p value.

# %% [markdown]
# For the sake of simplicity, we'll assume that $n_{1} = n_{2}$, which allows us to redefine equation (2.1) as
# $\begin{align*}
# t &= \frac{(\bar{x}_{1} - \bar{x}_{2})}{\sqrt{\frac{s_{1}^{2}}{n} + \frac{s_{2}^{2}}{n}}}\\
# &= \frac{\sqrt{n}(\bar{x}_{1} - \bar{x}_{2})}{\sqrt{s_{1}^{2} + s_{2}^{2}}}
# \end{align*}\tag{3.4}$
# which means the test statitic is now drawn from a t distribution with df degrees of freedom, where
# df is defined as
# $\begin{align*}
# df &= \left (n-1 \right ) \left (\frac{\left (s_{1}^{2} + s_{2}^{2}  \right )^{2}}{\left (s_{1}^{2} \right)^{2} + \left (s_{2}^{2}  \right )^{2}} \right )\\
# \end{align*}\tag{3.5}$
#
# For the emperical test, we can use the `scipy.stats.ttest_ind` function, which will return a p value.

# %%
def emp_ttest_ind(sample1, sample2):
    return scipy.stats.ttest_ind(sample1, sample2)[1]

# %% [markdown]
# ## 3.2 Nonparametric Test

# %%
def emp_ttest_ind_nonpar(sample1, sample2):
    scipy.stats.mannwhitneyu(sample1, sample2)[1]

# %% [markdown]
# ## 3.3 Effect Size

# %% [markdown]
# We again use Cohen's d for the effect size, although in this case, $s_{p}$ is substituted into equation (2.3) as the standard deviation, and we're looking at the difference of the two sample means.
# $\begin{align*}
# s_{p} &= \sqrt{\frac{\left (n_{1} - 1 \right)s_{1}^{2} + \left (n_{2} - 1 \right)s_{2}^{2}}{n_{1} + n_{2} - 2}}\\
# &= \sqrt{s_{1}^{2} + s_{2}^{2}}
# \end{align*}\tag{3.6}$
# $\begin{align*}
# d = \frac{\bar{x}_{1} - \bar{x}_{2}}{s_{p}}
# \end{align*}\tag{3.7}$

# %%
def cohen_ttest_ind(sample1, sample2):
    x1, s1, n1 = sample1.mean(), sample1.std(), len(sample1)
    x2, s2, n2 = sample2.mean(), sample2.std(), len(sample2)
    
    spool = np.sqrt(((n1-1) * np.square(s1) + (n2 - 1) * np.square(s2)) / (n1 + n2 - 2))
    return np.absolute(x1 - x2) / spool

# %% [markdown]
# ## 3.4 Noncentrality

# %% [markdown]
# The effect size, non-centrality parameter, for an independent sample t test where samples are the same size is once again related to the test statistic as
# $\begin{align*}
# \lambda &= \frac{t}{\sqrt{n}}\\
# &= \left (\frac{\sqrt{n} \left (\bar{x}_{1} - \bar{x}_{2} \right )}{\sqrt{s_{1}^{2} + s_{2}^{2}}} \right ) \left (\frac{1}{\sqrt{n}} \right )\\
# &= \left (\frac{\bar{x}_{1}^{2} - \bar{x}_{2}^{2}}{\sqrt{s_{1}^{2} + s_{2}^{2}}} \right )
# \end{align*}\tag{3.8}$

# %% [markdown]
# ## 3.5 Simulation Parameters

# %% [markdown]
# We will test distributions with means between 0 and 10, standard deviations between 5 and 15, and samples sizes between 60 and 100 observations.

# %%
def ttest_ind_simulate(mu_lim, sigma_lim, counts_lims):
    """..."""
    # Gets the distribution paramters
    sigma1 = np.random.uniform(*mu_lim, size=1)
    sigma2 = np.random.uniform(*sigma_lim, size=1)
    n = np.random.randint(*counts_lims)
    
    # Returns a pair of distributions
    samples =  [np.random.poisson(sigma1, n), np.random.poisson(sigma2, n)]
    return [sigma1, sigma2, n], samples

# %%
distributions['ttest_ind'] = {'emp_parameters': {},
                              'emp_test_fun': emp_ttest_ind,
                              'non_test_fun': emp_ttest_ind_nonpar,
                              'other_sim_parameters': {},
                              'sim_function': ttest_ind_simulate,
                              'sim_parameters': [[0.1, 3], [0.1, 3], [60, 100]],
                              'test_parameters': {},
                              'trad_test_fun': trad.calc_ttest_ind,     
                              'effect_size': cohen_ttest_ind
                              }

# %% [markdown]
# # 4. Analysis of Variance

# %% [markdown]
# Assume there exist a set of samples, $\{S_{1}, S_{2}, ..., S_{k} \}$ where there are a total of $N$ observations distributed over the $k$ groups. The $i$th sample, $S_{i}$ contains $n_{i}$ observations, and has a mean of $\bar{x}_{.i}$ and a standard deviation, $s_{i}$ where
#
# $\begin{align*}
# s_{i} = \sqrt{\frac{\sum_{j=1}^{n}{\left (x_{ij} - \bar{x}_{.i} \right)^{2}}}{n_{i}-1}}
# \end{align*}\tag{4.1}$
#
# A one-way Analysis of Variance (ANOVA) tests that at least one sample mean in a set of three or more are not equal. Assume that
#
# $\begin{matrix}
# \textbf{H}_{0} & \bar{x}_{1} = \bar{x}_{2} = ... \bar{x}_{k} & \\
# \textbf{H}_{1} & \bar{x}_{i} \neq \bar{x}_{j} & \exists i,j \epsilon [1, k], i \neq j
# \end{matrix} \tag{4.2}$

# %% [markdown]
# ## 4.1 Test Statistic

# %% [markdown]
# The test statistic for ANOVA is given by
# $\begin{align*}
# F &= \frac{\frac{\textrm{SS}_{\textrm{between}}}{\textrm{DF}_{\textrm{between}}}}{\frac{\textrm{SS}_{\textrm{within}}}{\textrm{DF}_{\textrm{within}}}}
# \end{align*}\tag{4.3}$
#
# where
# $\begin{align*}
# \textrm{SS}_{\textrm{total}} &= \sum_{i=1}^{k}{\sum_{j=1}^{n_{i}}{\left (x_{ij} - \bar{x}_{..} \right )^{2}}}\\
# \textrm{SS}_{\textrm{between}} &= \sum_{i=1}^{k}{n_{i}\left (\bar{x}_{.i} - \bar{x}_{..} \right )^{2}}\\
# \textrm{SS}_{\textrm{within}} &= \sum_{i=1}^{k}{\left [ \sum_{j=1}^{n_{i}}{\left (x_{ij} - \bar{x}_{.i} \right )^{2}}\right ]}
# \end{align*}\tag{4.4}$
#
# $\begin{align*}
# \textrm{DF}_{\textrm{total}} &= N - 1\\
# \textrm{DF}_{\textrm{between}} &= k - 1\\
# \textrm{DF}_{\textrm{within}} &= N - k
# \end{align*}\tag{4.5}$
#
# $\begin{align*}
# \textrm{SS}_{\textrm{total}} = \textrm{SS}_{\textrm{between}} + \textrm{SS}_{\textrm{within}}
# \end{align*}\tag{4.6}$
#
# $\begin{align*}
# \textrm{DF}_{\textrm{total}} = \textrm{DF}_{\textrm{between}} + \textrm{DF}_{\textrm{within}}
# \end{align*}\tag{4.7}$
#
# and test statistic is drawn from an $F$ distribution with $k - 1$ and $N - k$ degrees of freedom [[3](#Zar)].

# %%
def emp_anova(*samples):
    return scipy.stats.f_oneway(*samples)[1]

# %% [markdown]
# ## 4.2 Nonparametric Test

# %%
def emp_anova_nonpar(*samples):
    scipy.stats.kruskal(*samples)[1]

# %% [markdown]
# ## 4.3 Effect Size

# %% [markdown]
# For an analysis of variance, the effect size is given by
# $\begin{align*}
# f &= \sqrt{\frac{\sum_{i=1}^{k}{\left (\bar{x}_{.i} - \bar{x}_{..} \right )^{2}}}{ks^2}}\\
# \end{align*}\tag{4.8}$

# %%
def cohen_f2(*samples):
    k = len(samples)
    grand_mean = np.mean(samples)
    eff = np.sqrt(np.sum([np.square((sample.mean() - grand_mean) / sample.std()) for sample in samples]) / k)
    return eff

# %% [markdown]
# ## 4.4 Noncentrality Parameter

# %% [markdown]
# Under the alternatively hypothesis, the non-centrality $F'$ is given by
#
# $\begin{align*}
# F' = \left(\frac{\textrm{SS}_{\textrm{between}}}{\textrm{SS}_{\textrm{within}}} \right) \left (\frac{\textrm{DF}_{\textrm{within}}}{\textrm{DF}_{\textrm{between}}}{} \right )
# \end{align*}\tag{4.9}$
#
# For a given pair of hypotheses, the noncentrality parameter is defined according to equation (2.4), where the grand mean can be substituted for the the test mean. The overall effect size is therefore given as
# $\begin{align*}
# \lambda &= \sum_{i=1}^{k}{\lambda_{i}^{2}}\\
# &= \sum_{i=1}^{k}\left (\frac{\bar{x}_{i} - \bar{x}_{..}}{s_{i}} \right )^{2}
# \end{align*} \tag{4.10}$

# %% [markdown]
# ## 4.5 Simulation Parameters

# %% [markdown]
# We will simulate an ANOVA between 3 samples with means between 0 and 10, a common standard deviation between 5 and 15, and between 60 and 100 observations per sample.

# %%
def anova_simulation(mu_lim, sigma_lim, count_lims, num_pops):
    # Defines the distribtuion parameters
    mus = np.random.uniform(*mu_lim, size=num_pops)
    sigma = np.random.uniform(*sigma_lim)
    n = np.random.randint(*count_lims)
    
    # Draws samples which fit the population
    samples = [np.random.poisson(mu, n) for mu in mus]
    
    return [mus, sigma, n], samples

# %%
distributions['anova'] = {'emp_parameters': {},
                          'emp_test_fun': emp_anova,
                          'non_test_fun': emp_anova_nonpar,
                          'other_sim_parameters': {'num_pops': 3},
                          'sim_function': anova_simulation,
                          'sim_parameters': [[0, 3], [0.1, 3], [60, 100]],
                          'test_parameters': {},
                          'trad_test_fun': trad.calc_anova,
                          'effect_size': cohen_f2
                           }

# %% [markdown]
# # 5. Pearson's Correlation Coeffecient

# %% [markdown]
# Pearson's correlation coeffecient looks for a linear one-to-one relationship between two vectors, $x$ and $y$, both of size $n$. Closely related vectors have a correlation coeffecient with an absloute value of 1, unrelated data have a correlation coeffecient of 0.

# %% [markdown]
# ## 5.1 Test Statistic

# %% [markdown]
# The correlation coeffecient between the two vectors is given by
# $\begin{align*}
# r = \frac{\sum{xy}}{\sqrt{\sum{x^{2}}\sum{y^{2}}}}
# \end{align*}\tag{5.1}$
#
# We can test the hypotheses,
# $\begin{matrix}
# \textbf{H}_{0} & r = 0 \\
# \textbf{H}_{1} & x \neq 0\\
# \end{matrix} \tag{5.2}$
# with a test statistic drawn from the $t$ distribution with $n - 2$ degrees of freedom. The statistic is calculated as
# $\begin{align*}
# t = \frac{r\sqrt{n-2}}{\sqrt{1 - r^{2}}}
# \end{align*}\tag{5.3}$
#
# Scipy's `scipy.stats.pearsonr` can calculate the correlation coeffecient *and* a p value for the coeffecient.

# %%
def emp_pearson(*samples):
    return scipy.stats.pearsonr(*samples)[1]

# %% [markdown]
# ## Nonparametric Test

# %%
def emp_pearson_nonpar(*samples):
    scipy.stats.spearmanr(*samples)[1]

# %% [markdown]
# ## 5.2 Simulation Parameters

# %% [markdown]
# We're going to simulate regressions with slopes between 1 and 5, intercepts between -2 and 2, and normally distributed residuals with standard deviations between 10 and 100. There will be between 60 and 100 observations in each of the samples. We'll use `regress_simulate` to generate the distributions.

# %%
def regress_simulate(mu_lim, sigma_lim, count_lims, b_lims):
    # Calculates the distribution for the residuals
    sigma = np.random.uniform(*sigma_lim)
    n = np.random.randint(*count_lims)
    # Calculates the parameters for the line
    m = np.random.uniform(*mu_lim)
    b = np.random.randint(*b_lims)
    
    x = np.arange(-n, n, 2) / 10
    y = m*np.square(x) + b + np.random.randn(n)
    
    return [sigma, n, m, b], [x, y]

# %%
distributions['pearson'] = {'emp_parameters': {'draw_mode': 'matched'},
                            'emp_test_fun': emp_pearson,
                            'non_test_fun': emp_pearson_nonpar,
                            'other_sim_parameters':{'b_lims':[-2, 2]},
                            'sim_function': regress_simulate,
                            'sim_parameters': [[0.1, 5], [0.1, 5], [60, 100]],
                            'test_parameters': {},
                            'trad_test_fun': trad.calc_pearson,
                          }

# %% [markdown]
# # 6. Building Simulations

# %% [markdown]
# We will now build the simulations and look at the results.

# %%
# %%time

# for k, params in distributions.iteritems():
for k, params in [('ttest_1', distributions['ttest_1'])]:
    params['pop_params'] = []
    params['sample'] = []
    params['effs'] = []
    params['trad'] = []
    params['empp'] = []
    params['empn'] = []
    params['extp'] = []
    params['extn'] = []
    
    for i in xrange(1000):
        # Calculates the samples
        pop_params, samples = params['sim_function'](*params['sim_parameters'], **params['other_sim_parameters'])
        params['pop_params'].append(pop_params)
        params['sample'].append(samples)
        
        # Calculates the traditional power
        trad_power = params['trad_test_fun'](*samples, counts=counts, **params['test_parameters'])
        params['trad'].append(trad_power)
        
        # Calculates Cohen's effect
        if 'effect_size' in params:
            cohen_eff = params['effect_size'](*samples)
        else:
            cohen_eff = None
        
        # Extrapolates the effect from the test
        trad_eff = ap.z_effect(counts, trad_power)
        
        #  Calculates the emperical power using a parametric test
        pempr_power, pempr_counts = subsample_power(lambda x: params['emp_test_fun'](*x, **params['test_parameters']),
                                                  samples,
                                                  min_counts=5,
                                                  max_counts=55,
                                                  counts_interval=10,
                                                  num_runs=3,
                                                  num_iter=100,
                                                  **params['emp_parameters'])
        # Calculates the parmetric effect
        para_eff = ap.z_effect(pempr_counts, pempr_power)
        pextr_power = ap.z_power(counts, para_eff.mean())
        params['empp'].append(pempr_power)
        params['extp'].append(pextr_power)
        
#         # Calculates the emprical power using a nonparametric test
        nempr_power, nempr_counts = subsample_power(lambda x: params['emp_test_fun'](*x, **params['test_parameters']),
                                                  samples,
                                                  min_counts=5,
                                                  max_counts=55,
                                                  counts_interval=10,
                                                  num_runs=3,
                                                  num_iter=100,
                                                  **params['emp_parameters'])
        # Calculates the nonparametric effect
        nonp_eff = ap.z_effect(nempr_counts, nempr_power)
        next_power = ap.z_power(counts, nonp_eff.mean())
        params['empn'].append(nempr_power)
        params['extn'].append(next_power)
        

        # Updates the information
        params['effs'].append([cohen_eff, trad_eff, para_eff, nonp_eff])
    distributions[k] = params
    print k
# Out:
# ttest_1
# CPU times: user 9min 4s, sys: 663 ms, total: 9min 4s
# Wall time: 9min 4s

# %%
samples[0].__class__
# Out:
# numpy.ndarray

# %%
distributions['ttest_1']['empn'][0].shape
# Out:
# (3, 5)

# %%
eff = zip(*distributions['ttest_1']['effs'])[3][0]

# %%
print np.mean(eff), np.std(eff), eff.shape
# Out:
# 0.256208563066 0.115368891871 (11,)

# %%
ap.z_power(counts, np.mean(eff) + np.std(eff) / np.sqrt(11) * scipy.stats.t.ppf(0.975, 10)) - ap.z_power(counts, np.mean(eff))
# Out:
# array([ 0.01071142,  0.03889109,  0.06766517,  0.09564124,  0.12180389])

# %%
# fig1 = plt.figure()
# fig1.set_size_inches((4, 4))

samples = distributions['ttest_1']['sample']

effs = distributions['ttest_1']['effs']

trad = np.concatenate(distributions['ttest_1']['trad'])

empn_mean = np.concatenate([d.mean(0) for d in distributions['ttest_1']['empn']])
empn_conf = np.concatenate([d.std(0) / np.sqrt(5) * scipy.stats.t.ppf(0.975, 2) for d in distributions['ttest_1']['empn']])

emntrd_rt = np.concatenate([np.mean((np.vstack([t] * 3) - d) / np.vstack([t] * 3), 0) / np.sqrt(3)
                           for (t, d) in zip(*(distributions['ttest_1']['trad'], distributions['ttest_1']['empn']))])
emntrd_ci = np.concatenate([np.std((np.vstack([t] * 3) - d) / np.vstack([t] * 3), 0) / np.sqrt(3) * scipy.stats.t.ppf(0.975, 2) 
                            for (t, d) in zip(*(distributions['ttest_1']['trad'], distributions['ttest_1']['empn']))])
# 
extn_mean = np.concatenate([ap.z_power(counts, np.mean(eff)) for eff in zip(*effs)[3]])
extn_conf = np.concatenate([ap.z_power(counts, np.mean(eff) + np.std(eff) / np.sqrt(11) * scipy.stats.t.ppf(0.975, 10)) - 
                            ap.z_power(counts, np.mean(eff)) for eff in zip(*effs)[3]])

# %%
exntrd_r
# Out:
# [array([-0.08927213,  0.24654578,  0.22116598,  0.1566495 ,  0.10389599]),
#  array([  1.82035063e-01,   9.43725281e-02,   1.39918208e-02,
#           1.61980357e-03,   1.72695947e-04]),
#  array([  5.50921400e-02,   3.84511049e-03,   2.56471353e-05,
#           1.23059208e-07,   5.01685175e-10]),
#  array([ -1.08971600e-02,   9.58116170e-05,   4.55713955e-08,
#           1.40396583e-11,   3.18263934e-15]),
#  array([  2.58991537e-02,   8.51596061e-03,   1.34885261e-04,
#           1.44251384e-06,   1.31108799e-08]),
#  array([ 0.38076181,  0.26089422,  0.09593399,  0.03157147,  0.00992227]),
#  array([  6.71403047e-02,   5.61135644e-03,   4.74717918e-05,
#           2.62039190e-07,   1.14423023e-09]),
#  array([  1.09390161e-01,   2.78116396e-02,   1.21714068e-03,
#           3.94996440e-05,   1.14717290e-06]),
#  array([  1.45451560e-01,   1.16386148e-02,   2.00090363e-04,
#           2.63483342e-06,   3.02550982e-08]),
#  array([  1.60056278e-01,   5.38616741e-02,   4.47465281e-03,
#           2.86372766e-04,   1.60588264e-05]),
#  array([  2.20644672e-01,   4.17930975e-02,   2.29494267e-03,
#           9.83738719e-05,   3.72282482e-06]),
#  array([  9.44246903e-02,   3.45863761e-03,   2.25936984e-05,
#           1.04023371e-07,   3.80912524e-10]),
#  array([  8.61658526e-02,   7.61607163e-03,   1.03266297e-04,
#           1.00264527e-06,   7.87422379e-09]),
#  array([ 0.37286751,  0.21514034,  0.06032538,  0.01453864,  0.00329237]),
#  array([-0.34256308, -0.09562016,  0.00172158,  0.05147523,  0.07318934]),
#  array([-0.06784819,  0.20012693,  0.24784607,  0.26812846,  0.27795135]),
#  array([  2.07477039e-01,   7.31996619e-02,   7.32646111e-03,
#           5.58538720e-04,   3.76862169e-05]),
#  array([-0.17592387,  0.08046162,  0.1707824 ,  0.21376056,  0.23158153]),
#  array([ 0.00099572,  0.24628151,  0.29758161,  0.30712996,  0.30192578]),
#  array([ 0.43033045,  0.33523609,  0.16233096,  0.07740095,  0.03817514]),
#  array([ 0.13945311,  0.2460215 ,  0.1266798 ,  0.05209729,  0.01964819]),
#  array([  5.98014778e-02,   4.81169731e-04,   4.60348437e-07,
#           2.89817725e-10,   1.42441614e-13]),
#  array([  1.09541367e-01,   6.99576922e-03,   8.96627410e-05,
#           8.79307883e-07,   7.27961517e-09]),
#  array([  4.07188819e-02,   1.58768737e-02,   4.52396748e-04,
#           8.40928184e-06,   1.31217203e-07]),
#  array([ 0.36122697,  0.12074287,  0.01957402,  0.0028364 ,  0.00038514]),
#  array([  7.71355907e-02,   2.33701571e-03,   9.92708935e-06,
#           3.07215920e-08,   7.90898088e-11]),
#  array([-0.26381346, -0.03092668,  0.04549187,  0.08155204,  0.09548306]),
#  array([ 0.07515077,  0.22172738,  0.11982417,  0.05244221,  0.02119351]),
#  array([ 0.23309186,  0.20007511,  0.06946888,  0.01976345,  0.00512772]),
#  array([  2.28833046e-02,   1.52348280e-03,   7.14411830e-06,
#           2.50157083e-08,   7.00806450e-11]),
#  array([ 0.30427802,  0.15771624,  0.03229453,  0.00520139,  0.00074651]),
#  array([-0.22650909,  0.0231861 ,  0.10847976,  0.14678077,  0.1601433 ]),
#  array([ -2.05690095e-02,   5.00508591e-04,   7.77910619e-07,
#           8.37791022e-10,   7.18721379e-13]),
#  array([  1.53043635e-01,   1.98536797e-02,   6.84197356e-04,
#           1.96186513e-05,   4.98558048e-07]),
#  array([  7.04131326e-02,   1.71018436e-03,   5.19988785e-06,
#           1.12070122e-08,   2.00256478e-11]),
#  array([ 0.12523675,  0.16198756,  0.05788406,  0.01715642,  0.00477728]),
#  array([ 0.23818838,  0.286502  ,  0.16078876,  0.07911219,  0.03728548]),
#  array([-0.14610156,  0.15920118,  0.24135011,  0.26283614,  0.26239694]),
#  array([  1.07304660e-01,   3.58457024e-03,   1.92626503e-05,
#           7.01790929e-08,   2.04698110e-10]),
#  array([  1.90436600e-01,   2.42319767e-02,   8.77780977e-04,
#           2.51177810e-05,   6.19962831e-07]),
#  array([-0.16263161,  0.12850153,  0.08474219,  0.03781538,  0.0149458 ]),
#  array([  1.40301912e-01,   2.12523391e-02,   6.99692927e-04,
#           1.74022577e-05,   3.65264079e-07]),
#  array([-0.07613141,  0.24320822,  0.21766741,  0.15508217,  0.10449493]),
#  array([  5.56105067e-03,   2.37675803e-05,   2.07338239e-09,
#           1.13390778e-13,   0.00000000e+00]),
#  array([  1.25198831e-01,   3.90127713e-02,   2.33783436e-03,
#           1.02980764e-04,   3.95273791e-06]),
#  array([[[[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          ...,
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]]],
#
#
#
#         [[[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          ...,
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]]],
#
#
#
#         [[[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          ...,
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]]],
#
#
#
#         [[[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
# ...
#
#
#
#         [[[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          ...,
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]],
#
#
#          [[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           ...,
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#           [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            ...,
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#            [ nan,  nan,  nan, ...,  nan,  nan,  nan]]]]]),
#  array([-0.02053362,  0.1991374 ,  0.13790234,  0.07492181,  0.03759787]),
#  array([-0.00703127,  0.17969971,  0.10039572,  0.04359304,  0.01768034]),
#  array([  1.59908986e-01,   2.25158058e-02,   6.79370543e-04,
#           1.47904692e-05,   2.69462941e-07]),
#  array([  2.12320910e-01,   3.99422990e-02,   2.05292022e-03,
#           7.92523662e-05,   2.61485977e-06]),
#  array([  1.10317867e-01,   7.26534127e-03,   9.18156348e-05,
#           8.43425355e-07,   6.28964403e-09]),
#  array([ 0.0482414 ,  0.30715351,  0.37011606,  0.39029459,  0.39533607]),
#  array([  1.23807864e-01,   5.44565113e-03,   5.11381966e-05,
#           3.80512499e-07,   2.45626145e-09]),
#  array([-0.30003744, -0.08130883, -0.02496945, -0.00270698,  0.00423162]),
#  array([-0.1273745 ,  0.15743376,  0.10215018,  0.04864603,  0.0213239 ]),
#  array([  9.71470052e-02,   1.73956696e-02,   4.94568936e-04,
#           1.04222787e-05,   1.88736711e-07]),
#  array([ 0.42439991,  0.35239961,  0.16763772,  0.06905525,  0.02695628]),
#  array([  2.23667565e-02,   1.19306079e-03,   2.56363741e-06,
#           3.47807812e-09,   3.66506825e-12]),
#  array([ 0.46251561,  0.38530146,  0.1906226 ,  0.08117428,  0.03230293]),
#  array([  5.58185190e-02,   7.36190127e-03,   1.04837577e-04,
#           1.15234704e-06,   1.09968627e-08]),
#  array([  1.22005117e-01,   1.68128703e-02,   5.04812569e-04,
#           1.19403292e-05,   2.44451848e-07]),
#  array([ -5.20922083e-04,   7.41348763e-03,   1.07505063e-04,
#           9.39756490e-07,   6.73416726e-09]),
#  array([  2.04241613e-02,   8.35059088e-05,   2.46014974e-08,
#           5.08996549e-12,   8.14163551e-16]),
#  array([  1.10176310e-01,   6.99737662e-03,   8.96627410e-05,
#           8.79307883e-07,   7.27961517e-09]),
#  array([ 0.00330868,  0.27038311,  0.2761063 ,  0.23104858,  0.18160379]),
#  array([  3.96889146e-02,   1.73000039e-03,   5.05599136e-06,
#           9.48690826e-09,   1.39545042e-11]),
#  array([-0.56848241, -0.31503632, -0.17836138, -0.09330128, -0.04529611]),
#  array([ 0.01101383,  0.20233059,  0.13847232,  0.0790819 ,  0.04379551]),
#  array([-0.33852185, -0.10316075,  0.00216499,  0.06643417,  0.10110847]),
#  array([  1.49693373e-02,   1.17951717e-02,   3.10604704e-04,
#           5.96634597e-06,   1.01093353e-07]),
#  array([  1.62143748e-01,   3.96184073e-02,   2.45264066e-03,
#           1.17405345e-04,   4.83196694e-06]),
#  array([-0.13440282,  0.19911441,  0.19367002,  0.14140784,  0.09647373]),
#  array([  1.15233250e-01,   1.25004545e-02,   2.20084118e-04,
#           2.69603077e-06,   2.72271808e-08]),
#  array([ 0.29829918,  0.19645461,  0.0569269 ,  0.01410184,  0.00336811]),
#  array([-0.24304519, -0.02812531,  0.04496826,  0.0916963 ,  0.12001903]),
#  array([-0.0645621 ,  0.22457999,  0.29479717,  0.310788  ,  0.30810942]),
#  array([  1.09700215e-01,   7.63826747e-03,   1.19445106e-04,
#           1.54036235e-06,   1.70667082e-08]),
#  array([  1.75602150e-01,   4.82971867e-02,   4.00226610e-03,
#           2.92599597e-04,   1.98843916e-05]),
#  array([ 0.15984849,  0.2120505 ,  0.09735667,  0.03814064,  0.01459489]),
#  array([  1.96800660e-01,   3.15038528e-02,   1.33770907e-03,
#           4.39473500e-05,   1.26811924e-06]),
#  array([-0.12261399,  0.15912204,  0.23989182,  0.26655833,  0.27085957]),
#  array([ 0.04012932,  0.32576898,  0.35695234,  0.333745  ,  0.29852644]),
#  array([-0.26475633,  0.01386188,  0.1198125 ,  0.16751473,  0.18516988]),
#  array([-0.04630866,  0.33140353,  0.40172377,  0.42930962,  0.44149394])]

# %%
exntrd_r = []
exntrd_c = []
for i, (t, eff) in enumerate(zip(*(distributions['ttest_1']['trad'], distributions['ttest_1']['effs']))):
    if len(eff[3]) > 0:
        exntrd_r.append(np.mean([(t - ap.z_power(counts, e)) / t for e in eff[3]], 0))
        exntrd_c.append(np.std([(t - ap.z_power(counts, e)) / t for e in eff[3]], 0))
    else:
        exntrd_r.append(np.nan*np.ones(counts.shape))
        exntrd_c.append(np.nan*np.ones(counts.shape))
    
exntrd_r = np.concatenate(exntrd_r)
exntrd_c = np.concatenate(exntrd_c)

# %%
eff = distributions['ttest_1']['extn'][0]
t = distributions['ttest_1']['trad'][0]

# %%
np.std([(t - ap.z_power(counts, e)) / t for e in eff], 1)
# Out:
# array([ 0.0549749 ,  0.1367867 ,  0.07130357,  0.05355899,  0.05024777])

# %%
extp = np.concatenate(distributions['ttest_1']['extp'])

extn = np.concatenate(distributions['ttest_1']['extn'])

samples = distributions['ttest_1']['sample']

effs = distributions['ttest_1']['effs']

# %%
fig1 = plt.figure()
fig1.set_size_inches((4, 4))

ax1 = fig1.add_axes((0.125, 0.125, 0.75, 0.75))
loc=5
empn1 = distributions['ttest_1']['empn'][loc]
ax1.plot(np.arange(1.5, 102, 1.5), calc_ttest_1(samples[loc][0], 0, np.arange(1.5, 102, 1.5)), '-', color=[0.35, 0.35, 0.35])

ax1.fill_between(np.arange(1.5, 102, 1.5), 
                 ap.z_power(np.arange(1.5, 102, 1.5), effs[loc][3].mean() - effs[loc][3].std() / np.sqrt(len(effs[loc][2])) * 1.96),
                 ap.z_power(np.arange(1.5, 102, 1.5), effs[loc][3].mean() + effs[loc][3].std() / np.sqrt(len(effs[loc][2])) * 1.96),
                 alpha=0.25,
                 color='#e31a1c')
ax1.errorbar(np.arange(5, 55, 10), empn1.mean(0), yerr=(empn1.std(0) / np.sqrt(3)*scipy.stats.t.ppf(0.075, 2)),
            linestyle='none', marker='o', mec='#1f78b4', mfc='none', color='#1f78b4')
ax1.plot(np.arange(1.5, 102, 1.5), ap.z_power(np.arange(1.5, 102, 1.5), effs[loc][3].mean()), '-', color= '#e31a1c')
ax1.set_xlim([0, 50])
ax1.set_ylim([0, 1])

ax1.set_ylim([0, 1])
ax1.set_yticks(np.arange(0, 1.1, 0.25))
ax1.set_xlim([0, 50])
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.get_xaxis().set_tick_params(direction='out')
ax1.get_yaxis().set_tick_params(direction='out')
l = ax1.legend(['test-based', 'emprical', 'extrapolated'], loc=4, frameon=False)
ax1.set_xticklabels(map(int, ax1.get_xticks()), size=10)
ax1.set_yticklabels(ax1.get_yticks(), size=10)
# Out:
# [<matplotlib.text.Text at 0x11a7b6210>,
#  <matplotlib.text.Text at 0x11a349450>,
#  <matplotlib.text.Text at 0x11a346550>,
#  <matplotlib.text.Text at 0x11a7de350>,
#  <matplotlib.text.Text at 0x11c895c10>]

# %%
# ax1.fill_between(counts, 
#                  distributions['ttest_1']['empn'][loc].mean(0) - distributions['ttest_1']['empn'][loc].std(0) / np.sqrt(np.product(distributions['ttest_1']['empn'][loc].shape)) * scipy.stats.t.ppf(0.975, np.product(distributions['ttest_1']['empn'][loc].shape) - 1),
#                  distributions['ttest_1']['empn'][loc].mean(0) + distributions['ttest_1']['empn'][loc].std(0) / np.sqrt(np.product(distributions['ttest_1']['empn'][loc].shape)) * scipy.stats.t.ppf(0.975, np.product(distributions['ttest_1']['empn'][loc].shape) - 1),
#                  alpha=0.25,
#                  color='#1f78b4')
# ax1.plot(np.arange(1.5, 102, 1.5), ap.z_power(np.arange(1.5, 102, 1.5), effs[loc][3].mean()), '-.', color= '#e31a1c')
# ax1.plot(np.arange(1.5, 102, 1.5), ap.z_power(np.arange(1.5, 102, 1.5), effs[loc][3].mean()), color='#1f78b4')

ax1.set_ylim([0, 1])
ax1.set_yticks(np.arange(0, 1.1, 0.25))
ax1.set_xlim([0, 100])
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.get_xaxis().set_tick_params(direction='out')
ax1.get_yaxis().set_tick_params(direction='out')
l = ax1.legend(['test-based', 'nonparametric'], loc=4, frameon=False)
ax1.set_xticklabels(map(int, ax1.get_xticks()), size=10)
ax1.set_yticklabels(ax1.get_yticks(), size=10)

# ax1.text(2.5, 0.92, '(A)', size=15)
# ax1.set_ylabel('Power', size=12)
# ax1.set_xlabel('Sample Size', size=12)
# fig1.savefig('/Users/jwdebelius/Desktop/power_trace.pdf')
# Out:
# [<matplotlib.text.Text at 0x11a7b6210>,
#  <matplotlib.text.Text at 0x11a349450>,
#  <matplotlib.text.Text at 0x11a346550>,
#  <matplotlib.text.Text at 0x11a7de350>,
#  <matplotlib.text.Text at 0x11c895c10>]

# %%
exntrd_r.shape
# Out:
# (4411,)

# %%
trad.shape
# Out:
# (5000,)

# %%
fig2 = plt.figure()

ax2 = fig2.add_subplot(2, 3, 1)
ax3 = fig2.add_subplot(2, 3, 2)
ax4 = fig2.add_subplot(2, 3, 4)
ax5 = fig2.add_subplot(2, 3, 5)
ax6 = fig2.add_subplot(2, 3, 3)
ax7 = fig2.add_subplot(2, 3, 6)
# ax5 = fig2.add_subplot(2, 4, )
ax2.errorbar(trad, empn_mean, yerr=empn_conf, marker='', linestyle='none', color='#a6cee3')
ax2.plot(trad, empn_mean, 'o', mec='#1f78b4', mfc='none', markersize=4, alpha=0.2)

ax2.set_xlim([-0.05, 1.05])
ax2.set_ylim([-0.05, 1.1])
ax2.plot([-0.1, 1.1], [-0.1, 1.1], 'k-')
ax2.set_xticks(np.arange(0, 1.1, 0.25))
ax2.set_yticks(np.arange(0, 1.1, 0.25))
ax2.set_xticklabels('')
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.get_xaxis().set_tick_params(direction='out')
ax2.get_yaxis().set_tick_params(direction='out')
ax2.set_yticklabels(ax2.get_yticks(), size=10)
ax2.set_ylabel('Emperical Power', size=12)
ax2.text(0.05, 0.9, '(A)', size=15)

ax4.errorbar(trad, emntrd_rt, yerr=emntrd_ci, marker='', linestyle='none', color='#a6cee3')
ax4.plot(trad, emntrd_rt, 'o', mec='#1f78b4', mfc='none', markersize=4, alpha=0.2)
ax4.plot([0, 1], [0, 0], 'k-')
ax4.set_ylim([-1, 1])
ax4.set_xticks(np.arange(0, 1.1, 0.25))
ax4.set_yticks(np.arange(-1, 1.1, 0.5))
# ax4.set_xticklabels('')
ax4.set_yticklabels(ax4.get_yticks(), size=10)
ax4.set_xticklabels(ax4.get_xticks(), size=10)
ax4.spines['right'].set_visible(False)
ax4.spines['top'].set_visible(False)
ax4.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.get_xaxis().set_tick_params(direction='out')
ax4.get_yaxis().set_tick_params(direction='out')
ax4.set_ylabel('Relative Difference', size=12)
ax4.text(0.05, 0.8, '(C)', size=15)

ax3.errorbar(trad, extn_mean, yerr=extn_conf, marker='', linestyle='none', color='#fb9a99')
ax3.plot(trad, extn_mean, 'o', mec='#e31a1c', mfc='none', markersize=4)

ax3.plot([0, 1], [0, 1], 'k-')
ax3.set_xticks(np.arange(0, 1.1, 0.25))
ax3.set_yticks(np.arange(0, 1.1, 0.25))
ax3.set_yticklabels('')
ax3.set_xticklabels('')
ax3.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)
ax3.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.get_xaxis().set_tick_params(direction='out')
ax3.get_yaxis().set_tick_params(direction='out')
ax3.text(0.05, 0.9, '(B)', size=15)


ax5.errorbar(trad, exntrd_r, yerr=exntrd_c, marker='', linestyle='none', color='#fb9a99')
ax5.plot(trad, exntrd_r, 'o', mec='#e31a1c', mfc='none', ms=4)
ax5.plot([0, 1], [0, 0], 'k-')
ax5.set_xticks(np.arange(0, 1.1, 0.25))
ax5.set_ylim([-1, 1])
ax5.set_yticklabels('')
ax5.set_xticklabels(ax5.get_xticks(), size=10)
ax5.spines['right'].set_visible(False)
ax5.spines['top'].set_visible(False)
ax5.yaxis.set_ticks_position('left')
ax5.xaxis.set_ticks_position('bottom')
ax5.get_xaxis().set_tick_params(direction='out')
ax5.get_yaxis().set_tick_params(direction='out')
ax5.text(0.05, 0.8, '(D)', size=15)

# %%
ax4.plot(trad, (empn - trad) / trad, 'o', mec='#1f78b4', mfc='none', markersize=4, alpha=0.2)
ax4.plot([0, 1], [0, 0], 'k-')
ax4.set_ylim([-1, 1])
ax4.set_xticks(np.arange(0, 1.1, 0.25))
ax4.set_yticks(np.arange(-1, 1.1, 0.5))
# ax4.set_xticklabels('')
ax4.set_yticklabels(ax4.get_yticks(), size=10)
ax4.set_xticklabels(ax4.get_xticks(), size=10)
ax4.spines['right'].set_visible(False)
ax4.spines['top'].set_visible(False)
ax4.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.get_xaxis().set_tick_params(direction='out')
ax4.get_yaxis().set_tick_params(direction='out')
ax4.set_ylabel('Relative Difference', size=12)
ax4.text(0.05, 0.8, '(C)', size=15)

ax3.plot(trad, extn, 'o', mec='#e31a1c', mfc='none', markersize=4)
# ax3.plot(trad, extn, '.', color='#e31a1c')
ax3.plot([0, 1], [0, 1], 'k-')
ax3.set_xticks(np.arange(0, 1.1, 0.25))
ax3.set_yticks(np.arange(0, 1.1, 0.25))
ax3.set_yticklabels('')
ax3.set_xticklabels('')
ax3.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)
ax3.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.get_xaxis().set_tick_params(direction='out')
ax3.get_yaxis().set_tick_params(direction='out')
ax3.text(0.05, 0.9, '(B)', size=15)


ax5.plot(trad, (extn - trad) / trad, 'o', mec='#e31a1c', mfc='none', ms=4)
# ax5.plot(trad, (extn - trad) / trad, '.', color='#e31a1c')
ax5.plot([0, 1], [0, 0], 'k-')
ax5.set_xticks(np.arange(0, 1.1, 0.25))
ax5.set_ylim([-1, 1])
ax5.set_yticklabels('')
ax5.set_xticklabels(ax5.get_xticks(), size=10)
ax5.spines['right'].set_visible(False)
ax5.spines['top'].set_visible(False)
ax5.yaxis.set_ticks_position('left')
ax5.xaxis.set_ticks_position('bottom')
ax5.get_xaxis().set_tick_params(direction='out')
ax5.get_yaxis().set_tick_params(direction='out')
ax5.text(0.05, 0.8, '(D)', size=15)

l = ax5.set_xlabel('Test-based Power', size=12)
l.get_position()
l.set_position((-0.1, l.get_position()[1]))


ax6.plot(extn, empn, 'o', mec='#6a3d9a', mfc='none', ms=4)
ax6.plot([0, 1], [0, 1], 'k-')
ax6.set_xticks(np.arange(0, 1.1, 0.25))
ax6.set_yticks(np.arange(0, 1.1, 0.25))
ax6.set_yticklabels('')
ax6.set_xticklabels('')
ax6.spines['right'].set_visible(False)
ax6.spines['top'].set_visible(False)
ax6.yaxis.set_ticks_position('left')
ax6.xaxis.set_ticks_position('bottom')
ax6.get_xaxis().set_tick_params(direction='out')
ax6.get_yaxis().set_tick_params(direction='out')
ax6.text(0.05, 0.9, '(C)', size=15)
ax6.set_ylabel('')

ax7.plot(extn, (empn - extn) / extn, 'o', mec='#6a3d9a', mfc='none', ms=4)
# ax5.plot(trad, (extn - trad) / trad, '.', color='#e31a1c')
ax7.plot([0, 1], [0, 0], 'k-')
ax7.set_xticks(np.arange(0, 1.1, 0.25))
ax7.set_ylim([-1, 1])
ax7.set_yticklabels('')
ax7.set_xticklabels(ax5.get_xticks(), size=10)
ax7.spines['right'].set_visible(False)
ax7.spines['top'].set_visible(False)
ax7.yaxis.set_ticks_position('left')
ax7.xaxis.set_ticks_position('bottom')
ax7.get_xaxis().set_tick_params(direction='out')
ax7.get_yaxis().set_tick_params(direction='out')
ax7.text(0.05, 0.8, '(D)', size=15)

l = ax5.set_xlabel('Extrapolated Power', size=12)



# # fig2.set_size_inches((4, 6))

# # fig2.savefig('/Users/jwdebelius/Desktop/nonparametric.pdf')

# %%
print np.nanmin((empn - trad) / trad), np.nanmax((empn - trad) / trad)
# Out:
# -1.0 0.49201280035

# %%
print np.nanmin(((extn - trad) / trad)[trad > 0.5]), np.nanmax(((extn - trad) / trad)[trad > 0.5])
# Out:
# -0.58087736358 0.156138913098

# %%
empn[np.isnan(empn) == False]

# %%
trad[((np.isnan(empn) == False) & (np.isnan(trad) == False))]

# %%
mpn = empn[(np.isnan(empn) == False) & (np.isnan(trad) == False)]
trp = trad[(np.isnan(empn) == False) & (np.isnan(trad) == False)]
print np.mean(mpn / trp), np.std(mpn / trp)
print scipy.stats.pearsonr(mpn, trp)

# %%
print scipy.stats.pearsonr(trad, empn)
# print np.nanmean(empn / trad), np.nanstd(empn / trad) / np.sqrt(np.sum(np.isnan(empn/trad) == False)) * 1.96

# %%
fig3 = plt.figure()

ax2 = fig3.add_subplot(2, 2, 1)
ax3 = fig3.add_subplot(2, 2, 2)
ax4 = fig3.add_subplot(2, 2, 3)
ax5 = fig3.add_subplot(2, 2, 4)
# ax5 = fig2.add_subplot(2, 4, )

ax2.plot(trad, empp, 'o', mec='#e31a1c', mfc='none', markersize=4)
ax2.plot([0, 1], [0, 1], 'k-')
ax2.set_xticks(np.arange(0, 1.1, 0.25))
ax2.set_yticks(np.arange(0, 1.1, 0.25))
ax2.set_xticklabels('')
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.get_xaxis().set_tick_params(direction='out')
ax2.get_yaxis().set_tick_params(direction='out')
ax2.set_yticklabels(ax2.get_yticks(), size=10)
ax2.set_ylabel('Emperical Power', size=12)
ax2.text(0.05, 0.9, '(F)', size=15)

ax4.plot(trad, (empp - trad) / trad, 'o', mec='#e31a1c', mfc='none', markersize=4)
ax4.plot([0, 1], [0, 0], 'k-')
ax4.set_ylim([-1, 1])
ax4.set_xticks(np.arange(0, 1.1, 0.25))
ax4.set_yticks(np.arange(-1, 1.1, 0.5))
# ax4.set_xticklabels('')
ax4.set_yticklabels(ax4.get_yticks(), size=10)
ax4.set_xticklabels(ax4.get_xticks(), size=10)
ax4.spines['right'].set_visible(False)
ax4.spines['top'].set_visible(False)
ax4.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.get_xaxis().set_tick_params(direction='out')
ax4.get_yaxis().set_tick_params(direction='out')
ax4.set_ylabel('Relative Difference', size=12)
ax4.text(0.05, 0.8, '(G)', size=15)

ax3.plot(trad, extp, 'o', mec='#e31a1c', mfc='none', markersize=4)
# ax3.plot(trad, extp, '.', color='#e31a1c')
ax3.plot([0, 1], [0, 1], 'k-')
ax3.set_xticks(np.arange(0, 1.1, 0.25))
ax3.set_yticks(np.arange(0, 1.1, 0.25))
ax3.set_yticklabels('')
ax3.set_xticklabels('')
ax3.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)
ax3.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.get_xaxis().set_tick_params(direction='out')
ax3.get_yaxis().set_tick_params(direction='out')
ax3.text(0.05, 0.9, '(H)', size=15)


ax5.plot(trad, (extp - trad) / trad, 'o', mec='#e31a1c', mfc='none', ms=4)
# ax5.plot(trad, (extp - trad) / trad, '.', color='#e31a1c')
ax5.plot([0, 1], [0, 0], 'k-')
ax5.set_xticks(np.arange(0, 1.1, 0.25))
ax5.set_ylim([-1, 1])
ax5.set_yticklabels('')
ax5.set_xticklabels(ax5.get_xticks(), size=10)
ax5.spines['right'].set_visible(False)
ax5.spines['top'].set_visible(False)
ax5.yaxis.set_ticks_position('left')
ax5.xaxis.set_ticks_position('bottom')
ax5.get_xaxis().set_tick_params(direction='out')
ax5.get_yaxis().set_tick_params(direction='out')
ax5.text(0.05, 0.8, '(I)', size=15)

l = ax5.set_xlabel('Test-based Power', size=12)
l.get_position()
l.set_position((-0.1, l.get_position()[1]))
fig3.set_size_inches((4, 4))

fig3.savefig('/Users/jwdebelius/Desktop/parametric.pdf')

# %%
fig4 = plt.figure()

ax2 = fig4.add_subplot(2, 2, 1)
ax3 = fig4.add_subplot(2, 2, 2)
ax4 = fig4.add_subplot(2, 2, 3)
ax5 = fig4.add_subplot(2, 2, 4)
# ax5 = fig2.add_subplot(2, 4, )

ax2.plot(empn, empp, 'o', mec='#6a3d9a', mfc='none', markersize=4)
ax2.plot([0, 1], [0, 1], 'k-')
ax2.set_xticks(np.arange(0, 1.1, 0.25))
ax2.set_yticks(np.arange(0, 1.1, 0.25))
ax2.set_xticklabels('')
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.get_xaxis().set_tick_params(direction='out')
ax2.get_yaxis().set_tick_params(direction='out')
ax2.set_yticklabels(ax2.get_yticks(), size=10)
ax2.set_ylabel('Emperical Power', size=12)
ax2.text(0.05, 0.9, '(J)', size=15)

ax4.plot(empn, (empp - empn) / empn, 'o', mec='#6a3d9a', mfc='none', markersize=4)
ax4.plot([0, 1], [0, 0], 'k-')
ax4.set_ylim([-1, 1])
ax4.set_xticks(np.arange(0, 1.1, 0.25))
ax4.set_yticks(np.arange(-1, 1.1, 0.5))
# ax4.set_xticklabels('')
ax4.set_yticklabels(ax4.get_yticks(), size=10)
ax4.set_xticklabels(ax4.get_xticks(), size=10)
ax4.spines['right'].set_visible(False)
ax4.spines['top'].set_visible(False)
ax4.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.get_xaxis().set_tick_params(direction='out')
ax4.get_yaxis().set_tick_params(direction='out')
ax4.set_ylabel('Relative Difference', size=12)
ax4.text(0.05, 0.8, '(K)', size=15)

ax3.plot(extn, extp, 'o', mec='#6a3d9a', mfc='none', markersize=4)
# ax3.plot(empn, extp, '.', color='#6a3d9a')
ax3.plot([0, 1], [0, 1], 'k-')
ax3.set_xticks(np.arange(0, 1.1, 0.25))
ax3.set_yticks(np.arange(0, 1.1, 0.25))
ax3.set_yticklabels('')
ax3.set_xticklabels('')
ax3.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)
ax3.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.get_xaxis().set_tick_params(direction='out')
ax3.get_yaxis().set_tick_params(direction='out')
ax3.text(0.05, 0.9, '(L)', size=15)


ax5.plot(extn, (extp - extn) / extn, 'o', mec='#6a3d9a', mfc='none', ms=4)
# ax5.plot(empn, (extp - empn) / empn, '.', color='#6a3d9a')
ax5.plot([0, 1], [0, 0], 'k-')
ax5.set_xticks(np.arange(0, 1.1, 0.25))
ax5.set_ylim([-1, 1])
ax5.set_yticklabels('')
ax5.set_xticklabels(ax5.get_xticks(), size=10)
ax5.spines['right'].set_visible(False)
ax5.spines['top'].set_visible(False)
ax5.yaxis.set_ticks_position('left')
ax5.xaxis.set_ticks_position('bottom')
ax5.get_xaxis().set_tick_params(direction='out')
ax5.get_yaxis().set_tick_params(direction='out')
ax5.text(0.05, 0.8, '(M)', size=15)

l = ax5.set_xlabel('Test-based Power', size=12)
l.get_position()
l.set_position((-0.1, l.get_position()[1])) 
fig4.set_size_inches((4, 4)) 
fig4.savefig('/Users/jwdebelius/Desktop/ratio.pdf')

# %%
np.array(effs)

# %%
ax = plt.axes()
effs = np.array(effs)
# ax.plot(effs[:, 0], effs[:, 1], 'x')
ax.plot(effs[:, 0], effs[:, 2] * np.sqrt(2), 'o',  mec='#1f78b4', mfc='none')
ax.plot(effs[:, 0], effs[:, 3] * np.sqrt(2), '*', mec='#e31a1c', mfc='none', ms=15)

# %%
ratio = (np.concatenate(distributions['ttest_1']['empp']) / np.concatenate(distributions['ttest_1']['empn']))
ratio = ratio[np.isinf(ratio) == False]
print np.nanmean(ratio)
print np.nanstd(ratio) / np.sqrt(len(ratio)) * 1.96
# Out:
# 1.0044208972
# 0.00940787657572

# %%
from skbio.stats.power import subsample_power
k = 'anova'
params = distributions[k]

# %%
# %%time
params['pop_params'] = []
params['sample'] = []
params['effs'] = []
params['trad'] = []
params['empp'] = []
params['empn'] = []
params['extp'] = []
params['extn'] = []

for i in xrange(50):
    if i in {9, 19, 29, 39, 49}:
        print i + 1
    # Calculates the samples
    pop_params, samples = params['sim_function'](*params['sim_parameters'], **params['other_sim_parameters'])
    params['pop_params'].append(pop_params)
    params['sample'].append(samples)

    # Calculates the traditional power
    trad_power = params['trad_test_fun'](*samples, counts=counts, **params['test_parameters'])
    params['trad'].append(trad_power)

    # Calculates Cohen's effect
    if 'effect_size' in params:
        cohen_eff = params['effect_size'](*samples)
    else:
        cohen_eff = None

    # Extrapolates the effect from the test
    trad_eff = ap.z_effect(counts, trad_power)

    #  Calculates the emperical power using a parametric test
    pempr_power, pempr_counts = subsample_power(lambda x: params['emp_test_fun'](*x, **params['test_parameters']),
                                              samples,
                                              min_counts=5,
                                              max_counts=55,
                                              counts_interval=10,
                                              num_runs=3,
                                              num_iter=100,
                                              **params['emp_parameters'])
    # Calculates the parmetric effect
    para_eff = ap.z_effect(pempr_counts, pempr_power)
    pextr_power = ap.z_power(counts, para_eff.mean())
    params['empp'].append(pempr_power.mean(0))
    params['extp'].append(pextr_power)

    # Calculates the emprical power using a nonparametric test
    nempr_power, nempr_counts = subsample_power(lambda x: params['emp_test_fun'](*x, **params['test_parameters']),
                                              samples,
                                              min_counts=5,
                                              max_counts=55,
                                              counts_interval=10,
                                              num_runs=3,
                                              num_iter=100,
                                              **params['emp_parameters'])
    # Calculates the nonparametric effect
    nonp_eff = ap.z_effect(nempr_counts, nempr_power)
    next_power = ap.z_power(counts, nonp_eff.mean())
    params['empn'].append(nempr_power.mean(0))
    params['extn'].append(next_power)


    # Updates the information
    params['effs'].append([cohen_eff, trad_eff.mean(), para_eff.mean(), nonp_eff.mean()])
print 'done!'

# %%
# Updates the information
params['effs'].append([cohen_eff, trad_eff.mean(), para_eff.mean(), nonp_eff.mean()])

# %%
plt.plot(counts, params['trad'][0])
plt.plot(counts, params['trad'][1])
plt.plot(counts, params['trad'][2])
plt.plot(counts, params['trad'][3])
plt.plot(counts, params['trad'][4])
plt.plot(counts, params['trad'][5])
plt.plot(counts, params['trad'][6])
plt.plot(counts, params['trad'][7])
plt.plot(counts, params['trad'][8])
plt.plot(counts, params['trad'][9])

# %%
plt.plot(counts, params['empn'][0])
plt.plot(counts, params['empn'][1])
plt.plot(counts, params['empn'][2])
plt.plot(counts, params['empn'][3])
plt.plot(counts, params['empn'][4])
plt.plot(counts, params['empn'][5])
plt.plot(counts, params['empn'][6])
plt.plot(counts, params['empn'][7])
plt.plot(counts, params['empn'][8])
plt.plot(counts, params['empn'][9])

# %%
plt.plot(np.concatenate(params['empn']), np.concatenate(params['empp']), 'b.')
plt.plot(np.concatenate(params['empn']), np.concatenate(params['trad']), 'r.')
plt.plot(np.arange(0, 1.1, 0.1), np.arange(0, 1.1, 0.1), 'k-')

# %%
params['extp']
# Out:
# array([ 0.06450805,  0.10168112,  0.13978334,  0.17841009,  0.21720803])

# %%
params['empp']
# Out:
# array([ 0.07666667,  0.10333333,  0.16333333,  0.12333333,  0.17      ])

# %%
params['empn']
# Out:
# array([ 0.05333333,  0.09333333,  0.14666667,  0.15333333,  0.2       ])

# %%
% matplotlib inline

plt.plot(counts, params['trad'], 'bo')
# plt.plot(counts, params['extp'], 'g*')
plt.plot(counts, params['empp'], 'r^')
plt.plot(counts, params['empn'], 'c8')
plt.xlim([0, 50])
# Out:
# (0, 50)

# %% [markdown]
# # 7. Effect Size

# %% [markdown]
# I'm going to start by looking at the relationship between the test-based power, and the power we calculated from the emperical effect size.

# %%
# %matplotlib inline

# %%
fig1 = plt.figure()
x1 = []
y1 = []
for idx, test in enumerate(dists.index):
    x = np.concatenate(dists.loc[test, 'trad'])
    y = np.concatenate(dists.loc[test, 'exzt'])
    x1.append(x)
    y1.append(y)
    ax1 = fig1.add_subplot(2, 4, idx + 1)
    ax2 = fig1.add_subplot(2, 4, idx + 5)
    ax1.plot(np.arange(0, 1.1, 0.1), np.arange(0, 1.1, 0.1), 'k-')
    ax1.plot(x, y, '.', color=[0.5, 0.5, 0.5], alpha=0.1)
    ax2.plot(x, y / x, '.', color=[0.5, 0.5, 0.5], alpha=0.1)
    ax1.set_xlim([0, 1])
    ax1.set_ylim([0, 1])
    ax2.set_xlim([0, 1])
    ax2.set_ylim([0, 5])
    ax1.set_title(test)
    if idx > 0:
        ax1.set_yticklabels('')
        ax2.set_yticklabels('')
    ax1.set_xticklabels('')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-23dd8bdd9cea> in <module>()
#       2 x1 = []
#       3 y1 = []
# ----> 4 for idx, test in enumerate(dists.index):
#       5     x = np.concatenate(dists.loc[test, 'trad'])
#       6     y = np.concatenate(dists.loc[test, 'exzt'])
#
# NameError: name 'dists' is not defined

# %%
x = np.array(dists.loc[test, 'trad'])
y = np.array(dists.loc[test, 'exzt'])
i = np.arange(0, x.shape[0])

# %% [markdown]
# There is a strong ratio between test-based power, and the power calculated from that effect size. However, this is altered when tradtitional power is less than 0.05. So, let's remove values where traditional power is less than 0.05

# %%
x = np.concatenate(x1)
y = np.concatenate(y1)
i = (x > 0.01)
j = (x > 0.05)

# %%
i
# Out:
# array([ True,  True,  True, ..., False, False, False], dtype=bool)

# %%
print '%1.3f' % scipy.stats.pearsonr(y[i], x[i])[0]
print '%1.3f' % scipy.stats.pearsonr(y[j], x[j])[0]
print '%1.3f' % scipy.stats.pearsonr(y, x)[0]
# Out:
# 0.996
# 0.995
# 0.994

# %%
print '%1.3f +/- %1.3f' % (np.round(np.mean(y[i] / x[i]), 3), 
                           np.round(np.std(y[i] / x[i]) /
                                    np.sqrt(i.sum()) * scipy.stats.t.ppf(0.975, np.sum(i)), 3))
print '%1.3f +/- %1.3f' % (np.round(np.mean(y[j] / x[j]), 3), 
                           np.round(np.std(y[j] / x[j]) /
                                    np.sqrt(j.sum()) * scipy.stats.t.ppf(0.975, np.sum(j)), 3))
print '%1.3f +/- %1.3f' % (np.round(np.mean(y / x), 3), 
                           np.round(np.std(y / x) /
                                    np.sqrt(len(x)) * scipy.stats.t.ppf(0.975, len(x)), 3))
# Out:
# 1.090 +/- 0.009
# 0.997 +/- 0.002
# 2.628 +/- 0.577

# %% [markdown]
# Based on the graphs, it looks like the bias is largely associated with values for low power.
#
# I'd also like to

# %%
ax = plt.axes()
for idx, (test, color) in enumerate([('anova', 'r'), ('ttest_1', 'g'), ('ttest_ind', 'b')]):
    effs = np.array(dists.loc[test, 'effs'])
    x = effs[:, 0]
    y = effs[:, 2]
    n = effs.shape[1]
    ax.plot(x, y, 'o', mfc='none', mec=color)

# %%
xi = []
xj = []
yi = []
yj = []
for idx, (test, color, mod) in enumerate([('anova', 'r', 2), ('ttest_1', 'g', np.sqrt(2)), ('ttest_ind', 'b', 1)]):
    effs = np.array(dists.loc[test, 'effs'])
    x = effs[:, 0]
    y = effs[:, 2]
    n = effs.shape[1]
    i = (0.1 < x) * (x < 1.5)
    r1 = scipy.stats.pearsonr(x, y)[0]
    r2 = scipy.stats.pearsonr(x[i], y[i])[0]
    rat1 = x / y
    rat2 = x[i] / y[i]
    xi.append(x)
    yi.append(y / mod)
    xj.append(x[i])
    yj.append(y[i] / mod)
    
    print '%s   \t %1.3f \t %1.3f +/- %1.3f\t %1.3f \t %1.3f +/- %1.3f' % (
        test,
        r1, rat1.mean(), rat1.std() / np.sqrt(n) * scipy.stats.t.ppf(0.975, n-1),
        r2, rat2.mean(), rat2.std() / np.sqrt(i.sum()) * scipy.stats.t.ppf(0.975, i.sum() - 1)
    )
    print '%s   \t %1.3f \t %1.3f +/- %1.3f\t %1.3f \t %1.3f +/- %1.3f' % (
        test,
        r1, (rat1 * mod).mean(), (rat1 * mod).std() / np.sqrt(n) * scipy.stats.t.ppf(0.975, n-1),
        r2, (rat2 * mod).mean(), (rat2 * mod).std() / np.sqrt(i.sum()) * scipy.stats.t.ppf(0.975, i.sum() - 1)
    )
# Out:
# anova   	 0.996 	 0.558 +/- 0.156	 0.999 	 0.571 +/- 0.002
# anova   	 0.996 	 1.117 +/- 0.311	 0.999 	 1.141 +/- 0.005
# ttest_1   	 0.994 	 0.759 +/- 0.173	 0.997 	 0.763 +/- 0.003
# ttest_1   	 0.994 	 1.074 +/- 0.245	 0.997 	 1.079 +/- 0.004
# ttest_ind   	 0.975 	 1.031 +/- 0.722	 0.999 	 1.112 +/- 0.007
# ttest_ind   	 0.975 	 1.031 +/- 0.722	 0.999 	 1.112 +/- 0.007

# %%
1.147 - 0.005, 1.147 + 0.005
# Out:
# (1.1420000000000001, 1.152)

# %%
print np.round(scipy.stats.pearsonr(np.concatenate(xi), np.concatenate(yi))[0], 4)
print np.round(scipy.stats.pearsonr(np.concatenate(xj), np.concatenate(yj))[0], 4)
# Out:
# 0.9904
# 0.998

# %%
np.mean(np.concatenate(xi) / np.concatenate(yi))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-09525e1edd2d> in <module>()
# ----> 1 np.mean(np.concatenate(xi) / np.concatenate(yi))
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
np.std(np.concatenate(xi) / np.concatenate(yi)) / np.sqrt(n) * scipy.stats.t.ppf(0.975, n-1)
# Out:
# 0.00738938038257448

# %%
np.round((1.0783 - 0.470, 1.0783 + 0.470), 1)
# Out:
# array([ 0.6,  1.5])

# %%
np.mean(np.concatenate(xj) / np.concatenate(yj))
# Out:
# 1.1101088057875292

# %%
n = len(np.concatenate(xj))
np.std(np.concatenate(xj) / np.concatenate(yj)) / np.sqrt(n) * scipy.stats.t.ppf(0.975, n-1)
# Out:
# 0.0032908723949379255

# %%
xi = np.concatenate(xi)
yi = np.concatenate(yi)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-8461f9ae4ac2> in <module>()
# ----> 1 xi = np.concatenate(xi)
#       2 yi = np.concatenate(yi)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
rxyi = xi / yi
rxyi = np.mean(rxyi[np.isinf(rxyi) == False])
rxzi = xi / zi
rzyi = np.mean(rzyi[np.isinf(rzyi) == False])
ryzi = yi / zi
ryzi = np.mean(ryzi[np.isinf(ryzi) == False])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-c3cb5f38d386> in <module>()
# ----> 1 rxyi = xi / yi
#       2 rxyi = np.mean(rxyi[np.isinf(rxyi) == False])
#       3 rxzi = xi / zi
#       4 rzyi = np.mean(rzyi[np.isinf(rzyi) == False])
#       5 ryzi = yi / zi
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
mods = {'ANOVA', 2}

# %%
np.infmean([1, 2, np.inf])

# %% [markdown]
# ### 7.0.1 Emprical Power

# %%
xall = []
yall = []
zall = []
for idx, name in enumerate(dists.index.values):
    x = np.concatenate(dists.loc[name, 'trad'])
    y = np.concatenate(dists.loc[name, 'empr'])
    z = np.concatenate(dists.loc[name, 'extz'])
    xall.append(x)
    yall.append(y)
    zall.append(z)
    i = x > 0.05
    n = len(x)
    xi = x[i]
    yi = y[i]
    zi = z[i]
    ni = len(xi)
    
    rxy = x / y
    rxy = rxy[np.isinf(rxy) == False]
    rxz = x / z
    ryz = rxz[np.isinf(rxz) == False]
    ryz = y / z
    ryz = ryz[np.isinf(ryz) == False]
    
    rxyi = xi / yi
    rxyi = rxyi[np.isinf(rxyi) == False]
    rxzi = xi / zi
    rxzi = rxzi[np.isinf(rxzi) == False]
    ryzi = yi / zi
    ryzi = ryzi[np.isinf(ryzi) == False]
    
    print name
    print 'trad/empr, raw  ', np.round(
        (scipy.stats.pearsonr(x, y)[0], np.mean(rxy), np.std(rxy) / np.sqrt(len(rxy)) * 1.96), 3
        )
    print 'trad/empr, round', np.round(
        (scipy.stats.pearsonr(xi, yi)[0], np.mean(rxyi), np.std(rxyi) / np.sqrt(len(rxyi)) * 1.96), 3
        )
    print ''
    print 'trad/extr, raw  ', np.round(
        (scipy.stats.pearsonr(x, z)[0], np.mean(rxz), np.std(rxz) / np.sqrt(len(rxz)) * 1.96), 3
        )
    print 'trad/extr, round', np.round(
        (scipy.stats.pearsonr(xi, zi)[0], np.mean(rxzi), np.std(rxzi) / np.sqrt(len(rxzi)) * 1.96), 3
        )
    print ''
# Out:
# anova
# trad/empr, raw   [ 0.988  1.284  0.047]
# trad/empr, round [ 0.988  1.284  0.047]
#
# trad/extr, raw   [ 0.991  0.977  0.006]
# trad/extr, round [ 0.991  0.977  0.006]
#
# pearson
# trad/empr, raw   [ 0.985  1.05   0.004]
# trad/empr, round [ 0.985  1.05   0.004]
#
# trad/extr, raw   [ 0.961  1.069  0.004]
# trad/extr, round [ 0.961  1.069  0.004]
#
# ttest_1
# trad/empr, raw   [ 0.995  1.086  0.017]
# trad/empr, round [ 0.995  1.084  0.016]
#
# trad/extr, raw   [ 0.994  1.037  0.005]
# trad/extr, round [ 0.994  1.055  0.005]
#
# ttest_ind
# trad/empr, raw   [ 0.99   1.411  0.048]
# trad/empr, round [ 0.991  1.455  0.052]
#
# trad/extr, raw   [ 0.991  0.95   0.011]
# trad/extr, round [ 0.993  1.12   0.007]

# %%
rxya = np.concatenate(xall) / np.concatenate(yall)
rxya = rxya[np.isinf(rxya) == False]
rxza = np.concatenate(xall) / np.concatenate(zall)
rxza = rxza[np.isinf(rxza) == False]

print np.round(
    (scipy.stats.pearsonr(np.concatenate(xall), np.concatenate(yall))[0],
     np.mean(rxya),
     np.std(rxya) / np.sqrt(len(rxya)) * 1.96
     ), 3)
print np.round(
    (scipy.stats.pearsonr(np.concatenate(xall), np.concatenate(zall))[0],
     np.mean(rxza),
     np.std(rxza) / np.sqrt(len(rxza)) * 1.96
     ), 3)
# Out:
# [ 0.991  1.207  0.017]
# [ 0.99   1.008  0.004]

# %%
print np.isinf(x).any()
print np.isinf(y).any()
print np.isinf(x / y).any()
# Out:
# False
# False
# True

# %%
print scipy.stats.pearsonr(x, y)
print np.mean(x / y)
print np.std(x / y)
# Out:
# (0.99028026236992139, 0.0)
# inf
# nan

# %%
xall = []
yall = []
zall = []
for idx, (test, color, mod) in enumerate([('anova', 'r', 2), ('ttest_1', 'g', np.sqrt(2)), ('ttest_ind', 'b', 1)]):
    eff = np.array(dists.loc[test, 'effs'])
    x = eff[:, 0]
    y = eff[:, 1] / mod
    z = eff[:, 2] / mod
    i = (x > 0.1) * (x < 1.5)
    xi = x[i]
    yi = y[i]
    zi = z[i]
    
    xall.append(x)
    yall.append(y)
    zall.append(z)
    
    print test
    print np.round(
        (scipy.stats.pearsonr(x, y)[0],
         np.mean(x / y),
         np.std(x / y) / np.sqrt(len(x)) * 1.96
        ), 3)
    print np.round(
        (scipy.stats.pearsonr(xi, yi)[0],
         np.mean(xi / yi),
         np.std(xi / yi) / np.sqrt(len(xi)) * 1.96
        ), 3)
    print ''
    print np.round(
        (scipy.stats.pearsonr(x, y)[0],
         np.mean(z / y),
         np.std(z / y) / np.sqrt(len(x)) * 1.96
        ), 3)
    print np.round(
        (scipy.stats.pearsonr(xi, yi)[0],
         np.mean(zi / yi),
         np.std(zi / yi) / np.sqrt(len(xi)) * 1.96
        ), 3)
# Out:
# anova
# [ 0.988  1.172  0.022]
# [ 0.988  1.139  0.02 ]
#
# [ 0.988  1.052  0.019]
# [ 0.988  0.993  0.015]
# ttest_1
# [ 0.984  1.16   0.013]
# [ 0.981  1.162  0.012]
#
# [ 0.984  1.088  0.014]
# [ 0.981  1.077  0.01 ]
# ttest_ind
# [ 0.987  1.086  0.024]
# [ 0.994  1.195  0.018]
#
# [ 0.987  1.129  0.028]
# [ 0.994  1.071  0.012]

# %%
xall = np.concatenate(xall)
yall = np.concatenate(yall)
zall = np.concatenate(zall)
iall = (xall > 0.1) * (xall < 1.5)
print scipy.stats.pearsonr(xall, yall)[0]
# Out:
# 0.979037333945

# %%
print np.isinf(xall).any()
print np.isinf(yall).any()
print np.isinf(xall / yall).any()
# Out:
# False
# False
# False

# %%
np.round((np.mean((xall / yall)[np.isinf(xall / yall) == False]), np.std((xall / yall)[np.isinf(xall / yall) == False]) / np.sqrt(np.sum(np.isinf(xall / yall) == False)) * 1.96), 3)
# Out:
# array([ 1.139,  0.012])

# %%
print scipy.stats.pearsonr(xall[iall], yall[iall])[0]
print np.round((np.mean(xall[iall] / yall[iall]), np.std(xall[iall] / yall[iall]) / np.sqrt(len(xall[iall])) * 1.96), 3)
# Out:
# 0.978075873275
# [ 1.165  0.01 ]

# %%
print scipy.stats.pearsonr(zall, yall)[0]
print np.round((np.mean(zall / yall), np.std(zall / yall) / np.sqrt(len(zall)) * 1.96), 3)
# Out:
# 0.972239187639
# [ 1.09   0.012]

# %%
print scipy.stats.pearsonr(zall[iall], yall[iall])[0]
print np.round((np.mean(zall[iall] / yall[iall]), np.std(zall[iall] / yall[iall]) / np.sqrt(len(zall[iall])) * 1.96), 3)
# Out:
# 0.972504009307
# [ 1.047  0.007]

# %% [markdown]
# #References

# %% [markdown]
# 1. <a id="lui2014"></a>Lui, X.S. (2014) *[Statistical power analysis for the social and behavioral sciences: basic and advanced techniques](http://roger.ucsd.edu/search~S9?/Xstatistical%20power&=&Da=&Db=&searchscope=9&p=&SORT=D/Xstatistical%20power&=&Da=&Db=&searchscope=9&p=&SORT=D&SUBKEY=statistical+power/1%2C861%2C861%2CE/frameset&FF=Xstatistical%20power&=&Da=&Db=&searchscope=9&p=&SORT=D&1%2C1%2C)*. New York: Routledge. 378 pg.
# 2. <a id="zar1999"></a>Zar, J.H. (1999) "Multisample Hypothesis: The Analysis of Variance". Ch. 10. *Biostatistical Analysis*. 4th Ed. Upper Saddle River: Prentice Hall.
# 3. <a id="cohen"></a>Cohen, J. (1991) "[A Power Primer](https://thehubedu-production.s3.amazonaws.com/uploads/2522/a39eb8b3-385c-4db8-a4b4-0f5afe0c0af3/Cohen_1992_sample_size.pdf)" *Psychology Bulletin*. **112**: 155-159.
